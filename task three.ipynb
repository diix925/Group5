# %%
import pandas as pd

# %%
df = pd.read_csv("public-health-stores.csv")

# %%
df
# Out:
#                      الجهة    السنة   الفترة  \
# 0       أمانة منطقة القصيم     2021        1
# 1       أمانة منطقة القصيم     2021        2
# 2       أمانة منطقة القصيم     2021        3
# 3       أمانة منطقة القصيم     2021        4
# 4    بلدية محافظة الشماسيه     2021        1
# ..                     ...      ...      ...
# 108              بلدية قبة     2021        1
# 109              بلدية قبة     2021        2
# 110              بلدية قبة     2021        3
# 111              بلدية قبة     2021        4
# 112                المجموع  المجموع  المجموع
#
#      عدد محلات الصحة العامة التي منحت تراخيص (A0901)  \
# 0                                               4890
# 1                                               4867
# 2                                               4250
# 3                                               4915
# 4                                                 65
# ..                                               ...
# ...

# %%
df.drop ([2,3],axis=0,inplace=True)

# %%
df.head()
# Out:
#                    الجهة السنة الفترة  \
# 0     أمانة منطقة القصيم  2021      1
# 1     أمانة منطقة القصيم  2021      2
# 4  بلدية محافظة الشماسيه  2021      1
# 5  بلدية محافظة الشماسيه  2021      2
# 6  بلدية محافظة الشماسيه  2021      3
#
#    عدد محلات الصحة العامة التي منحت تراخيص (A0901)  \
# 0                                             4890
# 1                                             4867
# 4                                               65
# 5                                               65
# 6                                               65
#
#    عدد المحلات التي تم التفتيش عليها (A0902)  \
# 0                                       4370
# 1                                       4493
# 4                                         65
# 5                                         65
# 6                                         65
#
#    عدد الزيارات التفتيشية مجدولة (A0906)  عدد الزيارات التفتيشية شكوى (A0907)
# ...

# %%
df.drop(['الجهة' ,'الفترة'],axis=1,inplace=True)

# %%
df.head()
# Out:
#   السنة  عدد محلات الصحة العامة التي منحت تراخيص (A0901)  \
# 0  2021                                             4890
# 1  2021                                             4867
# 4  2021                                               65
# 5  2021                                               65
# 6  2021                                               65
#
#    عدد المحلات التي تم التفتيش عليها (A0902)  \
# 0                                       4370
# 1                                       4493
# 4                                         65
# 5                                         65
# 6                                         65
#
#    عدد الزيارات التفتيشية مجدولة (A0906)  عدد الزيارات التفتيشية شكوى (A0907)
# 0                                  13777                                 1154
# 1                                  16726                                  989
# 4                                    270                                    0
# ...

# %%
df = pd.read_csv("public-health-stores.csv")

# %%
df
# Out:
#                      الجهة    السنة   الفترة  \
# 0       أمانة منطقة القصيم     2021        1
# 1       أمانة منطقة القصيم     2021        2
# 2       أمانة منطقة القصيم     2021        3
# 3       أمانة منطقة القصيم     2021        4
# 4    بلدية محافظة الشماسيه     2021        1
# ..                     ...      ...      ...
# 108              بلدية قبة     2021        1
# 109              بلدية قبة     2021        2
# 110              بلدية قبة     2021        3
# 111              بلدية قبة     2021        4
# 112                المجموع  المجموع  المجموع
#
#      عدد محلات الصحة العامة التي منحت تراخيص (A0901)  \
# 0                                               4890
# 1                                               4867
# 2                                               4250
# 3                                               4915
# 4                                                 65
# ..                                               ...
# ...

# %%
df.dtypes
# Out:
# الجهة                                              object
# السنة                                              object
# الفترة                                             object
# عدد محلات الصحة العامة التي منحت تراخيص (A0901)     int64
# عدد المحلات التي تم التفتيش عليها (A0902)           int64
# عدد الزيارات التفتيشية مجدولة (A0906)               int64
# عدد الزيارات التفتيشية شكوى (A0907)                 int64
# dtype: object

# %%
df[["السنة" , "الفترة" ,"الجهة" ]] = df[["السنة" , "الفترة" ,"الجهة" ]].astype("int")

# %%
df.dtypes
# Out:
# الجهة                                              object
# السنة                                              object
# الفترة                                             object
# عدد محلات الصحة العامة التي منحت تراخيص (A0901)     int64
# عدد المحلات التي تم التفتيش عليها (A0902)           int64
# عدد الزيارات التفتيشية مجدولة (A0906)               int64
# عدد الزيارات التفتيشية شكوى (A0907)                 int64
# dtype: object
